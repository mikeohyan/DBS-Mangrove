# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
raw_x = np.arange(1500.)
x =

# %%
amplitude = .5;
period = .95;
phaseshift = 0.;
verticalshift = 0.;
# plt.plot(input, np.sin(np.mod(input,360.)*np.pi/180), 
plt.plot(raw_x, np.sin(x),'b--', raw_x, amplitude*np.sin((np.mod(raw_x*period, 360.)*np.pi/180.)-phaseshift)+verticalshift,'g')
plt.xlabel('time')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()
